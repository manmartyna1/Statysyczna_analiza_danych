# %% [markdown]
# ## Zapisz kopię pliku na dysku i zmień jego nazwę *CP9_ImieNazwisko.jpynb*

# %% [markdown]
# Analiza dotyczy zbioru danych, który zawiera informacje na temat batonów czekoladowych.\
# Zmiennne:
# * nazwa firmy produkującej batony czekoladowe
# * pochodzenie ziaren kakaowych lub nazwa batonu
# * numer referencyjny
# * rok przeglądu
# * procentowa zawartość kako w czekoladzie
# * lokalizacja firmy produkującej czekoladę
# * ocena batonu czekoladowego
# * pochodzenie ziaren kakaowca
#
# System oceny smaków kakao:\
# 5= Elita (Przekraczanie poza zwykłe granice)\
# 4= Premium (Doskonały rozwój smaku, charakteru i stylu)\
# 3 = zadowalający (3,0) do godnego pochwały (3,75) (dobrze wykonany, o specjalnych właściwościach)\
# 2= Rozczarowujący (Zadowalający, ale zawiera co najmniej jedną istotną wadę)\
# 1= Nieprzyjemny (przeważnie niesmaczny)\
# REF – wartość powiązana z datą wprowadzenia recenzji do bazy danych. Wyższy = nowszy.

# %% [markdown]
# ## 1. Wczytaj biblioteki:
# - numpy
# - pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Wczytaj jako ramkę danych zbiór znajdujący sie pod adresem:  (0,25 pkt.)
# https://raw.githubusercontent.com/clauswilke/dviz.supp/master/data-raw/cacao/flavors_of_cacao.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b14df0b-4d4c-49d1-98dd-652c5409a37e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b14df0b-4d4c-49d1-98dd-652c5409a37e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 3. Wyświetl 5 pierwszych wierszy

# %%
import pandas as pd

# %%
df = pd.read_csv('flavors_of_cacao.csv', sep=';', skiprows=8)
df.head()
# Out:
#      A. Morin,Kpime,1676,2015,70%,France,2.75, ,Togo Unnamed: 1 Unnamed: 2
# 0      A. Morin,Atsane,1676,2015,70%,France,3, ,Togo        NaN        NaN
# 1     A. Morin,Akata,1680,2015,70%,France,3.5, ,Togo        NaN        NaN
# 2    A. Morin,Quilla,1704,2015,70%,France,3.5, ,Peru        NaN        NaN
# 3  A. Morin,Carenero,1315,2014,70%,France,2.75,Cr...        NaN        NaN
# 4      A. Morin,Cuba,1315,2014,70%,France,3.5, ,Cuba        NaN        NaN

# %% [markdown]
# ## 4. Zmień nazwy kolumn na:   (0,5 pkt.)
#
# *   Element listy
# *   Element listy
#
#
# 'Company', 'Specific_Bean_Origin_or_Bar_Name', 'REF','Review_Date', 'Cocoa_Percentage', 'Company_Location','Rating', 'Bean_Type', 'Broad_Bean_Origin'
# ###i wyświetl 3 pierwsze wiersze

# %%
# Wczytaj plik z poprawnym separatorem i pomiń 7 nagłówków
df = pd.read_csv('flavors_of_cacao.csv', sep=',', skiprows=7)

# Nadaj poprawne nazwy kolumn
df.columns = [
    'Company',
    'Specific_Bean_Origin_or_Bar_Name',
    'REF',
    'Review_Date',
    'Cocoa_Percentage',
    'Company_Location',
    'Rating',
    'Bean_Type',
    'Broad_Bean_Origin'
]

# Wyświetl 3 pierwsze wiersze
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-30-d49d4c24aba7> in <cell line: 0>()
#       1 # Wczytaj plik z poprawnym separatorem i pomiń 7 nagłówków
# ----> 2 df = pd.read_csv('flavors_of_cacao.csv', sep=',', skiprows=7)
#       3
#       4 # Nadaj poprawne nazwy kolumn
#       5 df.columns = [
#
# ...

# %%
# Out:
#                               Location",Rating,"Bean Unnamed: 1 Unnamed: 2
# 0                                  Type","Broad Bean        NaN        NaN
# 1                                            Origin"        NaN        NaN
# 2  A. Morin,Agua Grande,1876,2016,63%,France,3.75...        NaN        NaN

# %% [markdown]
# ### 5. Wyfiltruj 3 wiersz (komórkę) dla zmiennej *Review_Date*    (0,25 pkt.)

# %% [markdown]
# ### 6. Wyfiltruj komórki obejmujące kolumny od 2 do 4 i wiersze od 1 do 5.    (0,25 pkt.)

# %% [markdown]
# ### 7. Wyświtl "kształt" zbioru - liczba wierszy i kolumn.      (0,25 pkt.)

# %% [markdown]
# ### 8. Wyświetl informcje o zbiorze danych
# ### Użyj funkcji head a następnie wyświetl informacje o brakach. Czy wyświetlają się informacje o "brakach" w zmiennej *Bean_Type* widoczne po użyciu funkcji head?   (0,25 pkt.)

# %% [markdown]
# ### 9. Wyfiltruj w zmiennych *Bean_Type* i *Broad_Bean_Origin* "niewidoczne braki danych" i zamień je na NA.    (0,5 pkt.)

# %% [markdown]
# ### 10. Sprawdź czy puste komórki występują jednoszcześnie w zmiennej *Bean_Type* i *Broad_Bean_Origin*. Jesli tak, to policz ile jest takich wierszy i usuń całe wiersze dla tych przypadków. Wyświetl ponownie kształ zbioru.    (0,5 pkt.)

# %% [markdown]
# ### 11. Sprawdź jakiego typu jest zmienna *Cocoa_Percentage* i wyjąsniej dlaczego taka? Zamień ją na float. Wyświetl 3 pierwsze wiersze. (0,5 pkt.)

# %% [markdown]
# ### 12. Dodaj do ramki danych nową kolumnę, która będzie zawierała informajce czy dana czekolada jest gorzka czy nie? W tym celu wykorzystaj zmienną *Cocoa_Percentage*.   (0,5 pkt.)

# %% [markdown]
# ### 13. Dodaj zmienną kategoryczną *Rating_Grade* opisującą ocenę czekolady. Przyjmij następujące przedziały i wyświetl 10 losowych wierszy. Nastepnie zlicz ile jest obserwacji dla poszczególnych kategorii.    (0,5 pkt.)
# System oceny smaków kakao:
# - 5 -  Elite (Przekraczanie poza zwykłe granice)
# - $<4;5)$ -  Premium (Doskonały rozwój smaku, charakteru i stylu)
# - $<3;4)$ - Satisfactory (3,0) do godnego pochwały (3,75) (dobrze wykonany, o specjalnych właściwościach)
# - $<2;3)$ - Disappointing (Zadowalający, ale zawiera co najmniej jedną istotną wadę)
# - $<1;2)$ - Unpleasant (przeważnie niesmaczny)

# %% [markdown]
# ### 14. Dla zmiennych numerycznych oblicz statystyki opisowe.  (0,25 pkt.)

# %% [markdown]
# ### 15. Policz średnią ocen dla czekolady mlecznej i gorzkiej (wykonaj pivot table lub tabelę grupującą)  (0,5 pkt.)

# %% [markdown]
# ### 16. Przygoyuj tablę raportującą która zliczy ilość unikalnych typów ocen () w poszczególnych latah dla czekolady mlecznej i gorzkiej.   (0,75 pkt.) - rysunek poglądowy, uwzględnij indeksy i odpowiednie kolumny
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Wyczyszczoną i zmodyfikowaną ramkę danych zapisz do pliku `new_cocao_XY.csv`,
# ### gdzie *XY* to Twoje inicjały (0,25 pkt.)

# %% [markdown]
# ### Pobierz plik z rozszerzeniem .IPYNB
#
#
# ### Oba pliki (*.csv, *.ipynb) umieść na UPEL
